# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (change 'your_dataset.csv' to your actual file path)
df = pd.read_csv("../Datasets/dataset_12500.csv")

# Shuffle the rows of the dataset
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# Save the shuffled dataset to a new CSV file
df_shuffled.to_csv("dataset_12500.csv", index=False)

# Check and print the number of 'good' and 'bad' URLs
num_good = df_shuffled[df_shuffled["label"] == "good"].shape[0]
num_bad = df_shuffled[df_shuffled["label"] == "bad"].shape[0]
print(f"Number of good URLs: {num_good}")
print(f"Number of bad URLs: {num_bad}")

# Display the head of the dataframe
print("\nHead of the shuffled dataframe:")
print(df_shuffled.head())

# Draw a histogram
labels = ["legitimate", "phishing"]
counts = [num_good, num_bad]

plt.bar(labels, counts, color=["green", "red"])
plt.title("Histogram of Legitimate and Phishing URLs")
plt.xlabel("URL Label")
plt.ylabel("Count")
plt.show()
# Out:
# Number of good URLs: 7501
# Number of bad URLs: 5000
#
# Head of the shuffled dataframe:
#                                                  url label
# 0  http://seekingalpha.com/author/nicholas-bodnar...  good
# 1  https://storage.googleapis.com/vb8-7hwe-nfuweh...   bad
# 2  http://update.troyvanspanje.com/login.php?id=3...   bad
# 3                       http://www.entraegypt.com/js   bad
# 4  https://simptaxt-err.tk/0utlook/index.php?logi...   bad

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (change 'your_dataset.csv' to your actual file path)
df = pd.read_csv("../Datasets/dataset_13500.csv")

# Shuffle the rows of the dataset
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# Save the shuffled dataset to a new CSV file
df_shuffled.to_csv("dataset_13500.csv", index=False)

# Check and print the number of 'good' and 'bad' URLs
num_good = df_shuffled[df_shuffled["label"] == "good"].shape[0]
num_bad = df_shuffled[df_shuffled["label"] == "bad"].shape[0]
print(f"Number of good URLs: {num_good}")
print(f"Number of bad URLs: {num_bad}")

# Display the head of the dataframe
print("\nHead of the shuffled dataframe:")
print(df_shuffled.head())

# Draw a histogram
labels = ["legitimate", "phishing"]
counts = [num_good, num_bad]

plt.bar(labels, counts, color=["green", "red"])
plt.title("Histogram of Legitimate and Phishing URLs")
plt.xlabel("URL Label")
plt.ylabel("Count")
plt.show()
# Out:
# Number of good URLs: 8501
# Number of bad URLs: 5000
#
# Head of the shuffled dataframe:
#                                                  url label
# 0  https://www.datanoc.com/dedicated-server-de526...  good
# 1                 https://www.gamma-service.it/news/  good
# 2                     https://www.ayu.ne.jp/support/  good
# 3                   http://embdestech.co.in/user.php   bad
# 4  https://snde-caeb.com.ogllvqo.cn/smbc/smbcupda...   bad

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (change 'your_dataset.csv' to your actual file path)
df = pd.read_csv("../Datasets/dataset_15430.csv")

# Shuffle the rows of the dataset
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# Save the shuffled dataset to a new CSV file
df_shuffled.to_csv("dataset_15430.csv", index=False)

# Check and print the number of 'good' and 'bad' URLs
num_good = df_shuffled[df_shuffled["label"] == "good"].shape[0]
num_bad = df_shuffled[df_shuffled["label"] == "bad"].shape[0]
print(f"Number of good URLs: {num_good}")
print(f"Number of bad URLs: {num_bad}")

# Display the head of the dataframe
print("\nHead of the shuffled dataframe:")
print(df_shuffled.head())

# Draw a histogram
labels = ["legitimate", "phishing"]
counts = [num_good, num_bad]

plt.bar(labels, counts, color=["green", "red"])
plt.title("Histogram of Legitimate and Phishing URLs")
plt.xlabel("URL Label")
plt.ylabel("Count")
plt.show()
# Out:
# Number of good URLs: 9715
# Number of bad URLs: 5715
#
# Head of the shuffled dataframe:
#                                                  url label
# 0    http://agwa.cl/img/admin/invoice/adeb/adobe.php   bad
# 1       http://magento.lcgin.xn--lockchain-zy5d.com/   bad
# 2                  http://nabagejec1893.blogspot.sg/   bad
# 3  http://www.Cisco.com/c/en/us/td/docs/voice_ip_...  good
# 4  http://www.metalsucks.net/2014/04/28/madhouse-...  good

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (change 'your_dataset.csv' to your actual file path)
df = pd.read_csv("../Datasets/dataset_20000.csv")

# Shuffle the rows of the dataset
df_shuffled = df.sample(frac=1).reset_index(drop=True)

# Save the shuffled dataset to a new CSV file
df_shuffled.to_csv("dataset_20000.csv", index=False)

# Check and print the number of 'good' and 'bad' URLs
num_good = df_shuffled[df_shuffled["label"] == "good"].shape[0]
num_bad = df_shuffled[df_shuffled["label"] == "bad"].shape[0]
print(f"Number of good URLs: {num_good}")
print(f"Number of bad URLs: {num_bad}")

# Display the head of the dataframe
print("\nHead of the shuffled dataframe:")
print(df_shuffled.head())

# Draw a histogram
labels = ["legitimate", "phishing"]
counts = [num_good, num_bad]

plt.bar(labels, counts, color=["green", "red"])
plt.title("Histogram of Legitimate and Phishing URLs")
plt.xlabel("URL Label")
plt.ylabel("Count")
plt.show()
# Out:
# Number of good URLs: 12000
# Number of bad URLs: 8000
#
# Head of the shuffled dataframe:
#                                                  url label
# 0         http://www.m.servlces.runescape.com-mv.ru/   bad
# 1  https://www.facebook.com/photo?fbid=3037752120...  good
# 2                  https://www.creusot-montceau.org/  good
# 3     http://www.broelio.de/unternehmensphilosophie/  good
# 4  https://www.vetassess.com.au/skills-assessment...  good
