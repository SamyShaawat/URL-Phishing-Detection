# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# Print the current working directory
# print(os.getcwd())
os.chdir("../Data_Analysis")
from data_analysis import analyze_dataset

# %%
analyze_dataset("../Dataset_with_Features/dataset_10000.csv")
# Out:
# Number of rows: 10000
# Number of columns: 25
# <style type="text/css">
# #T_6ad56 th {
#   border: 2px solid white;
# }
# #T_6ad56 td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_6ad56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ad56_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_6ad56_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_6ad56_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_6ad56_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_6ad56_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_6ad56_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_6ad56_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_6ad56_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_11430.csv")
# Out:
# Number of rows: 11430
# Number of columns: 25
# <style type="text/css">
# #T_9ea5f th {
#   border: 2px solid white;
# }
# #T_9ea5f td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_9ea5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ea5f_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_9ea5f_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_9ea5f_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_9ea5f_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_9ea5f_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_9ea5f_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_9ea5f_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_9ea5f_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_11481.csv")
# Out:
# Number of rows: 11481
# Number of columns: 25
# <style type="text/css">
# #T_7fc09 th {
#   border: 2px solid white;
# }
# #T_7fc09 td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_7fc09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fc09_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_7fc09_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_7fc09_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_7fc09_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_7fc09_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_7fc09_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_7fc09_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_7fc09_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_20000.csv")
# Out:
# Number of rows: 20000
# Number of columns: 25
# <style type="text/css">
# #T_42058 th {
#   border: 2px solid white;
# }
# #T_42058 td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_42058">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42058_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_42058_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_42058_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_42058_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_42058_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_42058_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_42058_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_42058_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_370344.csv")
# Out:
# Number of rows: 370344
# Number of columns: 25
# d:\GP\URL-Phishing-Detection\Data_Analysis\data_analysis.py:8: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <style type="text/css">
# #T_881bf th {
#   border: 2px solid white;
# }
# #T_881bf td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_881bf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_881bf_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_881bf_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_881bf_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_881bf_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_881bf_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_881bf_level0_col5" class="col_heading level0 col5" >count.</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_420464.csv")
# Out:
# Number of rows: 420464
# Number of columns: 25
# d:\GP\URL-Phishing-Detection\Data_Analysis\data_analysis.py:8: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# <style type="text/css">
# #T_919cb th {
#   border: 2px solid white;
# }
# #T_919cb td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_919cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_919cb_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_919cb_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_919cb_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_919cb_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_919cb_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_919cb_level0_col5" class="col_heading level0 col5" >count.</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_73575.csv")
# Out:
# Number of rows: 73575
# Number of columns: 25
# <style type="text/css">
# #T_916dc th {
#   border: 2px solid white;
# }
# #T_916dc td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_916dc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_916dc_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_916dc_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_916dc_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_916dc_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_916dc_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_916dc_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_916dc_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_916dc_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_80000.csv")
# Out:
# Number of rows: 80000
# Number of columns: 25
# <style type="text/css">
# #T_cf2c6 th {
#   border: 2px solid white;
# }
# #T_cf2c6 td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_cf2c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf2c6_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_cf2c6_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_cf2c6_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_cf2c6_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_cf2c6_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_cf2c6_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_cf2c6_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_cf2c6_level0_col7" class="col_heading level0 col7" >count@</th>
# ...

# %%
analyze_dataset("../Dataset_with_Features/dataset_95910.csv")
# Out:
# Number of rows: 95910
# Number of columns: 25
# <style type="text/css">
# #T_aa550 th {
#   border: 2px solid white;
# }
# #T_aa550 td {
#   border: 2px solid white;
# }
# </style>
# <table id="T_aa550">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa550_level0_col0" class="col_heading level0 col0" >url</th>
#       <th id="T_aa550_level0_col1" class="col_heading level0 col1" >label</th>
#       <th id="T_aa550_level0_col2" class="col_heading level0 col2" >use_of_ip</th>
#       <th id="T_aa550_level0_col3" class="col_heading level0 col3" >abnormal_url</th>
#       <th id="T_aa550_level0_col4" class="col_heading level0 col4" >google_index</th>
#       <th id="T_aa550_level0_col5" class="col_heading level0 col5" >count.</th>
#       <th id="T_aa550_level0_col6" class="col_heading level0 col6" >count-www</th>
#       <th id="T_aa550_level0_col7" class="col_heading level0 col7" >count@</th>
# ...
